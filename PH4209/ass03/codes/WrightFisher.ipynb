# %% [markdown]
# # Assignment 03
#
# Sabarno Saha, 22MS037.
#
# ## Problem 1
#
# Moran's Process with selection.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
# NJIT is needed, otherwise the complete double loop takes around 20 mins to run
from numba import njit


# Use the scienceplots package for nicer plot themes.
import scienceplots
plt.style.use(['science'])

# Just some config to make plots legible in pdfs
plt.rcParams.update({'font.size': 20,  'axes.labelweight': 'bold', 'font.family': 'sans-serif', 'legend.fontsize': 15})

# %%
# @njit
def moran_fitness(pop,T,r):
    """
    moran_neutral 
    Returns a population updated by the Moran Process

    Parameters
    ----------
    pop : array
        Initial Population
    T : int
        Maximum Number of generations(to prevent infinite loops)
    r: float
        Relative fitness of type A compared to type B. If r > 1, type A is more fit than type B, if r < 1, type A is less fit than type B, and if r = 1, both types have equal fitness (neutral case).
    """
    pop = np.asarray(pop)
    freq = np.zeros((T,2))
    N = len(pop)
    freq[0,0] = np.sum(pop)
    freq[0,1] =  N - freq[0,0]
    # print(freq[0,0],freq[0,1])
    for t in range(1,T):

        
        
        total_fitness = freq[t-1,0]*r + freq[t-1,1]
        reproduction_probs =[
            (freq[t-1,0]*r)/total_fitness, # Probability of choosing type A for reproduction
            (freq[t-1,1])/total_fitness     # Probability of choosing type B for reproduction
        ]
        death_probs = [
            freq[t-1,0]/N, # Probability of choosing type A for death
            freq[t-1,1]/N  # Probability of choosing type B for death
        ]
        
        reproduce_idx = np.random.choice([0,1], p=reproduction_probs)
    
        
        # Choose an individual to die
        die_idx = np.random.choice([0,1], p=death_probs)
        
        # Update population counts
        if reproduce_idx == 0 and die_idx == 1:
            # Type 0 reproduces, type 1 dies
            freq[t,0] = freq[t-1,0] + 1
            freq[t,1] = freq[t-1,1] - 1
        elif reproduce_idx == 1 and die_idx == 0:
            # Type 1 reproduces, type 0 dies
            freq[t,0] = freq[t-1,0] - 1
            freq[t,1] = freq[t-1,1] + 1
        else:
            # print("No change in population counts")
            # No change in population counts
            freq[t,0] = freq[t-1,0]
            freq[t,1] = freq[t-1,1]
        # print(freq[t,0],freq[t,1])
        # Check for fixation
        if freq[t,0] == 0 or freq[t,0] == N:
            # print(f"Fixation reached at generation {t}")
            # returns truncated frequency array
            return freq[:t+1,:]/N
    print("Maximum generations reached without fixation")
    return freq/N

# %%
def invasion_probability(r,i,N):
    """
    invasion_probability 
    Returns the probability of invasion of a single mutant of type A in a population of type B in the Moran Process with selection.

    Parameters
    ----------
    r: float
        Relative fitness of type A compared to type B. 
    i: int
        Initial number of mutants of type A in the population.
    N: int
        Total population size.
    """
    prob = (1 - r**(-i))/(1 - r**(-N))
    return prob

# %%
# population size
N_moran = 100

# Maximum number of generations(to prevent infinite loops)
T_max = int(1e6)

# Number of runs
Nt_moran = 1000

# Relative fitness of type A compared to type B
r = 1.01

# %%
# %%time

## Find fixation probabilites
fixation_probs = np.zeros(2)
sample_trajectory = []

for run in range(Nt_moran):
    pop_0 = np.zeros(N_moran)
    #ensuring that only one mutant of type A is present.
    pop_0[0] = 1
    
    # Run the Moran process
    freq = moran_fitness(pop_0,T_max,r)
    fixation_probs += freq[-1]
    
    print(f"Run {run+1}/{Nt_moran}")
  
# Normalize to get probabilities  
fixation_probs /= Nt_moran
# Out:
# Run 1/1000
# Run 2/1000
# Run 3/1000
# Run 4/1000
# Run 5/1000
# Run 6/1000
# Run 7/1000
# Run 8/1000
# Run 9/1000
# Run 10/1000
# Run 11/1000
# Run 12/1000
# Run 13/1000
# Run 14/1000
# Run 15/1000
# Run 16/1000
# Run 17/1000
# Run 18/1000
# Run 19/1000
# Run 20/1000
# Run 21/1000
# Run 22/1000
# Run 23/1000
# Run 24/1000
# Run 25/1000
# Run 26/1000
# Run 27/1000
# Run 28/1000
# Run 29/1000
# Run 30/1000
# Run 31/1000
# Run 32/1000
# Run 33/1000
# Run 34/1000
# Run 35/1000
# Run 36/1000
# Run 37/1000
# Run 38/1000
# Run 39/1000
# Run 40/1000
# Run 41/1000
# Run 42/1000
# Run 43/1000
# Run 44/1000
# Run 45/1000
# Run 46/1000
# Run 47/1000
# Run 48/1000
# Run 49/1000
# Run 50/1000
# Run 51/1000
# Run 52/1000
# Run 53/1000
# Run 54/1000
# Run 55/1000
# Run 56/1000
# Run 57/1000
# Run 58/1000
# Run 59/1000
# Run 60/1000
# Run 61/1000
# Run 62/1000
# Run 63/1000
# Run 64/1000
# Run 65/1000
# Run 66/1000
# Run 67/1000
# Run 68/1000
# Run 69/1000
# Run 70/1000
# Run 71/1000
# Run 72/1000
# Run 73/1000
# Run 74/1000
# Run 75/1000
# Run 76/1000
# Run 77/1000
# Run 78/1000
# Run 79/1000
# Run 80/1000
# Run 81/1000
# Run 82/1000
# Run 83/1000
# Run 84/1000
# Run 85/1000
# Run 86/1000
# Run 87/1000
# Run 88/1000
# Run 89/1000
# Run 90/1000
# Run 91/1000
# Run 92/1000
# Run 93/1000
# Run 94/1000
# Run 95/1000
# Run 96/1000
# Run 97/1000
# Run 98/1000
# Run 99/1000
# Run 100/1000
# Run 101/1000
# Run 102/1000
# Run 103/1000
# Run 104/1000
# Run 105/1000
# Run 106/1000
# Run 107/1000
# Run 108/1000
# Run 109/1000
# Run 110/1000
# Run 111/1000
# Run 112/1000
# Run 113/1000
# Run 114/1000
# Run 115/1000
# Run 116/1000
# Run 117/1000
# Run 118/1000
# Run 119/1000
# Run 120/1000
# Run 121/1000
# Run 122/1000
# Run 123/1000
# Run 124/1000
# Run 125/1000
# Run 126/1000
# Run 127/1000
# Run 128/1000
# Run 129/1000
# Run 130/1000
# Run 131/1000
# Run 132/1000
# Run 133/1000
# Run 134/1000
# Run 135/1000
# Run 136/1000
# Run 137/1000
# Run 138/1000
# Run 139/1000
# Run 140/1000
# Run 141/1000
# Run 142/1000
# Run 143/1000
# Run 144/1000
# Run 145/1000
# Run 146/1000
# Run 147/1000
# Run 148/1000
# Run 149/1000
# Run 150/1000
# Run 151/1000
# Run 152/1000
# Run 153/1000
# Run 154/1000
# Run 155/1000
# Run 156/1000
# Run 157/1000
# Run 158/1000
# Run 159/1000
# Run 160/1000
# Run 161/1000
# Run 162/1000
# Run 163/1000
# Run 164/1000
# Run 165/1000
# Run 166/1000
# Run 167/1000
# Run 168/1000
# Run 169/1000
# Run 170/1000
# Run 171/1000
# Run 172/1000
# Run 173/1000
# Run 174/1000
# Run 175/1000
# Run 176/1000
# Run 177/1000
# Run 178/1000
# Run 179/1000
# Run 180/1000
# Run 181/1000
# Run 182/1000
# Run 183/1000
# Run 184/1000
# Run 185/1000
# Run 186/1000
# Run 187/1000
# Run 188/1000
# Run 189/1000
# Run 190/1000
# Run 191/1000
# Run 192/1000
# Run 193/1000
# Run 194/1000
# Run 195/1000
# Run 196/1000
# Run 197/1000
# Run 198/1000
# Run 199/1000
# Run 200/1000
# Run 201/1000
# Run 202/1000
# Run 203/1000
# Run 204/1000
# Run 205/1000
# Run 206/1000
# Run 207/1000
# Run 208/1000
# Run 209/1000
# Run 210/1000
# Run 211/1000
# Run 212/1000
# Run 213/1000
# Run 214/1000
# Run 215/1000
# Run 216/1000
# Run 217/1000
# Run 218/1000
# Run 219/1000
# Run 220/1000
# Run 221/1000
# Run 222/1000
# Run 223/1000
# Run 224/1000
# Run 225/1000
# Run 226/1000
# Run 227/1000
# Run 228/1000
# Run 229/1000
# Run 230/1000
# Run 231/1000
# Run 232/1000
# Run 233/1000
# Run 234/1000
# Run 235/1000
# Run 236/1000
# Run 237/1000
# Run 238/1000
# Run 239/1000
# Run 240/1000
# Run 241/1000
# Run 242/1000
# Run 243/1000
# Run 244/1000
# Run 245/1000
# Run 246/1000
# Run 247/1000
# Run 248/1000
# Run 249/1000
# Run 250/1000
# Run 251/1000
# Run 252/1000
# Run 253/1000
# Run 254/1000
# Run 255/1000
# Run 256/1000
# Run 257/1000
# Run 258/1000
# Run 259/1000
# Run 260/1000
# Run 261/1000
# Run 262/1000
# Run 263/1000
# Run 264/1000
# Run 265/1000
# Run 266/1000
# Run 267/1000
# Run 268/1000
# Run 269/1000
# Run 270/1000
# Run 271/1000
# Run 272/1000
# Run 273/1000
# Run 274/1000
# Run 275/1000
# Run 276/1000
# Run 277/1000
# Run 278/1000
# Run 279/1000
# Run 280/1000
# Run 281/1000
# Run 282/1000
# Run 283/1000
# Run 284/1000
# Run 285/1000
# Run 286/1000
# Run 287/1000
# Run 288/1000
# Run 289/1000
# Run 290/1000
# Run 291/1000
# Run 292/1000
# Run 293/1000
# Run 294/1000
# Run 295/1000
# Run 296/1000
# Run 297/1000
# Run 298/1000
# Run 299/1000
# Run 300/1000
# Run 301/1000
# Run 302/1000
# Run 303/1000
# Run 304/1000
# Run 305/1000
# Run 306/1000
# Run 307/1000
# Run 308/1000
# Run 309/1000
# Run 310/1000
# Run 311/1000
# Run 312/1000
# Run 313/1000
# Run 314/1000
# Run 315/1000
# Run 316/1000
# Run 317/1000
# Run 318/1000
# Run 319/1000
# Run 320/1000
# Run 321/1000
# Run 322/1000
# Run 323/1000
# Run 324/1000
# Run 325/1000
# Run 326/1000
# Run 327/1000
# Run 328/1000
# Run 329/1000
# Run 330/1000
# Run 331/1000
# Run 332/1000
# Run 333/1000
# Run 334/1000
# Run 335/1000
# Run 336/1000
# Run 337/1000
# Run 338/1000
# Run 339/1000
# Run 340/1000
# Run 341/1000
# Run 342/1000
# Run 343/1000
# Run 344/1000
# Run 345/1000
# Run 346/1000
# Run 347/1000
# Run 348/1000
# Run 349/1000
# Run 350/1000
# Run 351/1000
# Run 352/1000
# Run 353/1000
# Run 354/1000
# Run 355/1000
# Run 356/1000
# Run 357/1000
# Run 358/1000
# Run 359/1000
# Run 360/1000
# Run 361/1000
# Run 362/1000
# Run 363/1000
# Run 364/1000
# Run 365/1000
# Run 366/1000
# Run 367/1000
# Run 368/1000
# Run 369/1000
# Run 370/1000
# Run 371/1000
# Run 372/1000
# Run 373/1000
# Run 374/1000
# Run 375/1000
# Run 376/1000
# Run 377/1000
# Run 378/1000
# Run 379/1000
# Run 380/1000
# Run 381/1000
# Run 382/1000
# Run 383/1000
# Run 384/1000
# Run 385/1000
# Run 386/1000
# Run 387/1000
# Run 388/1000
# Run 389/1000
# Run 390/1000
# Run 391/1000
# Run 392/1000
# Run 393/1000
# Run 394/1000
# Run 395/1000
# Run 396/1000
# Run 397/1000
# Run 398/1000
# Run 399/1000
# Run 400/1000
# Run 401/1000
# Run 402/1000
# Run 403/1000
# Run 404/1000
# Run 405/1000
# Run 406/1000
# Run 407/1000
# Run 408/1000
# Run 409/1000
# Run 410/1000
# Run 411/1000
# Run 412/1000
# Run 413/1000
# Run 414/1000
# Run 415/1000
# Run 416/1000
# Run 417/1000
# Run 418/1000
# Run 419/1000
# Run 420/1000
# Run 421/1000
# Run 422/1000
# Run 423/1000
# Run 424/1000
# Run 425/1000
# Run 426/1000
# Run 427/1000
# Run 428/1000
# Run 429/1000
# Run 430/1000
# Run 431/1000
# Run 432/1000
# Run 433/1000
# Run 434/1000
# Run 435/1000
# Run 436/1000
# Run 437/1000
# Run 438/1000
# Run 439/1000
# Run 440/1000
# Run 441/1000
# Run 442/1000
# Run 443/1000
# Run 444/1000
# Run 445/1000
# Run 446/1000
# Run 447/1000
# Run 448/1000
# Run 449/1000
# Run 450/1000
# Run 451/1000
# Run 452/1000
# Run 453/1000
# Run 454/1000
# Run 455/1000
# Run 456/1000
# Run 457/1000
# Run 458/1000
# Run 459/1000
# Run 460/1000
# Run 461/1000
# Run 462/1000
# Run 463/1000
# Run 464/1000
# Run 465/1000
# Run 466/1000
# Run 467/1000
# Run 468/1000
# Run 469/1000
# Run 470/1000
# Run 471/1000
# Run 472/1000
# Run 473/1000
# Run 474/1000
# Run 475/1000
# Run 476/1000
# Run 477/1000
# Run 478/1000
# Run 479/1000
# Run 480/1000
# Run 481/1000
# Run 482/1000
# Run 483/1000
# Run 484/1000
# Run 485/1000
# Run 486/1000
# Run 487/1000
# Run 488/1000
# Run 489/1000
# Run 490/1000
# Run 491/1000
# Run 492/1000
# Run 493/1000
# Run 494/1000
# Run 495/1000
# Run 496/1000
# Run 497/1000
# Run 498/1000
# Run 499/1000
# Run 500/1000
# Run 501/1000
# Run 502/1000
# Run 503/1000
# Run 504/1000
# Run 505/1000
# Run 506/1000
# Run 507/1000
# Run 508/1000
# Run 509/1000
# Run 510/1000
# Run 511/1000
# Run 512/1000
# Run 513/1000
# Run 514/1000
# Run 515/1000
# Run 516/1000
# Run 517/1000
# Run 518/1000
# Run 519/1000
# Run 520/1000
# Run 521/1000
# Run 522/1000
# Run 523/1000
# Run 524/1000
# Run 525/1000
# Run 526/1000
# Run 527/1000
# Run 528/1000
# Run 529/1000
# Run 530/1000
# Run 531/1000
# Run 532/1000
# Run 533/1000
# Run 534/1000
# Run 535/1000
# Run 536/1000
# Run 537/1000
# Run 538/1000
# Run 539/1000
# Run 540/1000
# Run 541/1000
# Run 542/1000
# Run 543/1000
# Run 544/1000
# Run 545/1000
# Run 546/1000
# Run 547/1000
# Run 548/1000
# Run 549/1000
# Run 550/1000
# Run 551/1000
# Run 552/1000
# Run 553/1000
# Run 554/1000
# Run 555/1000
# Run 556/1000
# Run 557/1000
# Run 558/1000
# Run 559/1000
# Run 560/1000
# Run 561/1000
# Run 562/1000
# Run 563/1000
# Run 564/1000
# Run 565/1000
# Run 566/1000
# Run 567/1000
# Run 568/1000
# Run 569/1000
# Run 570/1000
# Run 571/1000
# Run 572/1000
# Run 573/1000
# Run 574/1000
# Run 575/1000
# Run 576/1000
# Run 577/1000
# Run 578/1000
# Run 579/1000
# Run 580/1000
# Run 581/1000
# Run 582/1000
# Run 583/1000
# Run 584/1000
# Run 585/1000
# Run 586/1000
# Run 587/1000
# Run 588/1000
# Run 589/1000
# Run 590/1000
# Run 591/1000
# Run 592/1000
# Run 593/1000
# Run 594/1000
# Run 595/1000
# Run 596/1000
# Run 597/1000
# Run 598/1000
# Run 599/1000
# Run 600/1000
# Run 601/1000
# Run 602/1000
# Run 603/1000
# Run 604/1000
# Run 605/1000
# Run 606/1000
# Run 607/1000
# Run 608/1000
# Run 609/1000
# Run 610/1000
# Run 611/1000
# Run 612/1000
# Run 613/1000
# Run 614/1000
# Run 615/1000
# Run 616/1000
# Run 617/1000
# Run 618/1000
# Run 619/1000
# Run 620/1000
# Run 621/1000
# Run 622/1000
# Run 623/1000
# Run 624/1000
# Run 625/1000
# Run 626/1000
# Run 627/1000
# Run 628/1000
# Run 629/1000
# Run 630/1000
# Run 631/1000
# Run 632/1000
# Run 633/1000
# Run 634/1000
# Run 635/1000
# Run 636/1000
# Run 637/1000
# Run 638/1000
# Run 639/1000
# Run 640/1000
# Run 641/1000
# Run 642/1000
# Run 643/1000
# Run 644/1000
# Run 645/1000
# Run 646/1000
# Run 647/1000
# Run 648/1000
# Run 649/1000
# Run 650/1000
# Run 651/1000
# Run 652/1000
# Run 653/1000
# Run 654/1000
# Run 655/1000
# Run 656/1000
# Run 657/1000
# Run 658/1000
# Run 659/1000
# Run 660/1000
# Run 661/1000
# Run 662/1000
# Run 663/1000
# Run 664/1000
# Run 665/1000
# Run 666/1000
# Run 667/1000
# Run 668/1000
# Run 669/1000
# Run 670/1000
# Run 671/1000
# Run 672/1000
# Run 673/1000
# Run 674/1000
# Run 675/1000
# Run 676/1000
# Run 677/1000
# Run 678/1000
# Run 679/1000
# Run 680/1000
# Run 681/1000
# Run 682/1000
# Run 683/1000
# Run 684/1000
# Run 685/1000
# Run 686/1000
# Run 687/1000
# Run 688/1000
# Run 689/1000
# Run 690/1000
# Run 691/1000
# Run 692/1000
# Run 693/1000
# Run 694/1000
# Run 695/1000
# Run 696/1000
# Run 697/1000
# Run 698/1000
# Run 699/1000
# Run 700/1000
# Run 701/1000
# Run 702/1000
# Run 703/1000
# Run 704/1000
# Run 705/1000
# Run 706/1000
# Run 707/1000
# Run 708/1000
# Run 709/1000
# Run 710/1000
# Run 711/1000
# Run 712/1000
# Run 713/1000
# Run 714/1000
# Run 715/1000
# Run 716/1000
# Run 717/1000
# Run 718/1000
# Run 719/1000
# Run 720/1000
# Run 721/1000
# Run 722/1000
# Run 723/1000
# Run 724/1000
# Run 725/1000
# Run 726/1000
# Run 727/1000
# Run 728/1000
# Run 729/1000
# Run 730/1000
# Run 731/1000
# Run 732/1000
# Run 733/1000
# Run 734/1000
# Run 735/1000
# Run 736/1000
# Run 737/1000
# Run 738/1000
# Run 739/1000
# Run 740/1000
# Run 741/1000
# Run 742/1000
# Run 743/1000
# Run 744/1000
# Run 745/1000
# Run 746/1000
# Run 747/1000
# Run 748/1000
# Run 749/1000
# Run 750/1000
# Run 751/1000
# Run 752/1000
# Run 753/1000
# Run 754/1000
# Run 755/1000
# Run 756/1000
# Run 757/1000
# Run 758/1000
# Run 759/1000
# Run 760/1000
# Run 761/1000
# Run 762/1000
# Run 763/1000
# Run 764/1000
# Run 765/1000
# Run 766/1000
# Run 767/1000
# Run 768/1000
# Run 769/1000
# Run 770/1000
# Run 771/1000
# Run 772/1000
# Run 773/1000
# Run 774/1000
# Run 775/1000
# Run 776/1000
# Run 777/1000
# Run 778/1000
# Run 779/1000
# Run 780/1000
# Run 781/1000
# Run 782/1000
# Run 783/1000
# Run 784/1000
# Run 785/1000
# Run 786/1000
# Run 787/1000
# Run 788/1000
# Run 789/1000
# Run 790/1000
# Run 791/1000
# Run 792/1000
# Run 793/1000
# Run 794/1000
# Run 795/1000
# Run 796/1000
# Run 797/1000
# Run 798/1000
# Run 799/1000
# Run 800/1000
# Run 801/1000
# Run 802/1000
# Run 803/1000
# Run 804/1000
# Run 805/1000
# Run 806/1000
# Run 807/1000
# Run 808/1000
# Run 809/1000
# Run 810/1000
# Run 811/1000
# Run 812/1000
# Run 813/1000
# Run 814/1000
# Run 815/1000
# Run 816/1000
# Run 817/1000
# Run 818/1000
# Run 819/1000
# Run 820/1000
# Run 821/1000
# Run 822/1000
# Run 823/1000
# Run 824/1000
# Run 825/1000
# Run 826/1000
# Run 827/1000
# Run 828/1000
# Run 829/1000
# Run 830/1000
# Run 831/1000
# Run 832/1000
# Run 833/1000
# Run 834/1000
# Run 835/1000
# Run 836/1000
# Run 837/1000
# Run 838/1000
# Run 839/1000
# Run 840/1000
# Run 841/1000
# Run 842/1000
# Run 843/1000
# Run 844/1000
# Run 845/1000
# Run 846/1000
# Run 847/1000
# Run 848/1000
# Run 849/1000
# Run 850/1000
# Run 851/1000
# Run 852/1000
# Run 853/1000
# Run 854/1000
# Run 855/1000
# Run 856/1000
# Run 857/1000
# Run 858/1000
# Run 859/1000
# Run 860/1000
# Run 861/1000
# Run 862/1000
# Run 863/1000
# Run 864/1000
# Run 865/1000
# Run 866/1000
# Run 867/1000
# Run 868/1000
# Run 869/1000
# Run 870/1000
# Run 871/1000
# Run 872/1000
# Run 873/1000
# Run 874/1000
# Run 875/1000
# Run 876/1000
# Run 877/1000
# Run 878/1000
# Run 879/1000
# Run 880/1000
# Run 881/1000
# Run 882/1000
# Run 883/1000
# Run 884/1000
# Run 885/1000
# Run 886/1000
# Run 887/1000
# Run 888/1000
# Run 889/1000
# Run 890/1000
# Run 891/1000
# Run 892/1000
# Run 893/1000
# Run 894/1000
# Run 895/1000
# Run 896/1000
# Run 897/1000
# Run 898/1000
# Run 899/1000
# Run 900/1000
# Run 901/1000
# Run 902/1000
# Run 903/1000
# Run 904/1000
# Run 905/1000
# Run 906/1000
# Run 907/1000
# Run 908/1000
# Run 909/1000
# Run 910/1000
# Run 911/1000
# Run 912/1000
# Run 913/1000
# Run 914/1000
# Run 915/1000
# Run 916/1000
# Run 917/1000
# Run 918/1000
# Run 919/1000
# Run 920/1000
# Run 921/1000
# Run 922/1000
# Run 923/1000
# Run 924/1000
# Run 925/1000
# Run 926/1000
# Run 927/1000
# Run 928/1000
# Run 929/1000
# Run 930/1000
# Run 931/1000
# Run 932/1000
# Run 933/1000
# Run 934/1000
# Run 935/1000
# Run 936/1000
# Run 937/1000
# Run 938/1000
# Run 939/1000
# Run 940/1000
# Run 941/1000
# Run 942/1000
# Run 943/1000
# Run 944/1000
# Run 945/1000
# Run 946/1000
# Run 947/1000
# Run 948/1000
# Run 949/1000
# Run 950/1000
# Run 951/1000
# Run 952/1000
# Run 953/1000
# Run 954/1000
# Run 955/1000
# Run 956/1000
# Run 957/1000
# Run 958/1000
# Run 959/1000
# Run 960/1000
# Run 961/1000
# Run 962/1000
# Run 963/1000
# Run 964/1000
# Run 965/1000
# Run 966/1000
# Run 967/1000
# Run 968/1000
# Run 969/1000
# Run 970/1000
# Run 971/1000
# Run 972/1000
# Run 973/1000
# Run 974/1000
# Run 975/1000
# Run 976/1000
# Run 977/1000
# Run 978/1000
# Run 979/1000
# Run 980/1000
# Run 981/1000
# Run 982/1000
# Run 983/1000
# Run 984/1000
# Run 985/1000
# Run 986/1000
# Run 987/1000
# Run 988/1000
# Run 989/1000
# Run 990/1000
# Run 991/1000
# Run 992/1000
# Run 993/1000
# Run 994/1000
# Run 995/1000
# Run 996/1000
# Run 997/1000
# Run 998/1000
# Run 999/1000
# Run 1000/1000
# CPU times: user 18.4 s, sys: 128 ms, total: 18.6 s
# Wall time: 18.5 s

# %%
# %%time

## Get a sample trajectory when invasion takes place.
sample_trajectory = []

for run in range(Nt_moran):
    pop_0 = np.zeros(N_moran)
    # Ensure that only one mutant of type A is present.
    pop_0[0] = 1
    
    # Run the Moran process
    freq = moran_fitness(pop_0,T_max,r)
    if freq[-1,0] == 1.0:
        sample_trajectory = freq
        break
    print(f"Run {run+1}/{Nt_moran}")
# Out:
# Run 1/5000
# Run 2/5000
# Run 3/5000
# Run 4/5000
# Run 5/5000
# Run 6/5000
# Run 7/5000
# Run 8/5000
# Run 9/5000
# Run 10/5000
# Run 11/5000
# Run 12/5000
# Run 13/5000
# Run 14/5000
# Run 15/5000
# Run 16/5000
# Run 17/5000
# Run 18/5000
# Run 19/5000
# Run 20/5000
# Run 21/5000
# Run 22/5000
# Run 23/5000
# Run 24/5000
# Run 25/5000
# Run 26/5000
# Run 27/5000
# Run 28/5000
# Run 29/5000
# Run 30/5000
# Run 31/5000
# Run 32/5000
# Run 33/5000
# Run 34/5000
# Run 35/5000
# CPU times: user 727 ms, sys: 3.98 ms, total: 731 ms
# Wall time: 729 ms

# %%
fig, axes = plt.subplots(figsize=(16,9))
axes.plot(sample_trajectory[:,0], label=f"Frequency of Type A with fitness = {r:.2f}", color='c')
axes.plot(sample_trajectory[:,1], label=f"Frequency of Type B with fitness = {1.0}", color='r')
axes.legend()
axes.set_xlabel("Generations")
axes.set_ylabel("Frequency")
axes.set_title("Example of Invasion in Moran Process(with Selection): Frequency vs Generations")
# fig.savefig("images/moran_selection.png", dpi=300)
# Out:
# Text(0.5, 1.0, 'Example of Invasion in Moran Process(with Selection): Frequency vs Generations')

# %%
# Invasion probability from analytical formula
prob = invasion_probability(r,1,N_moran)
prob
# Out:
# 0.015708656559792596

# %%
fig, axes = plt.subplots(figsize=(6,7))
axes.bar([0,1], fixation_probs, color=['c','r'])
axes.annotate(f"{fixation_probs[0]:.3f}", xy=(0, fixation_probs[0]), xytext=(0, fixation_probs[0]+0.05), ha='center', fontsize=15, fontweight='bold', color='black')
axes.annotate(f"{fixation_probs[1]:.3f}", xy=(1, fixation_probs[1]), xytext=(1, fixation_probs[1]+0.05), ha='center', fontsize=15, fontweight='bold', color='black')
axes.axhline(y=prob, color='r', linestyle='--', label=f'Theoretical Fixation Probability = {prob:.3f}')
axes.set_xticks([0,1])
axes.set_xticklabels(['Type A','Type B'])
axes.set_ylabel("Fixation Probability")
axes.set_ylim(0,1.3)
axes.set_title("\n Invasion Probabilities from Moran Process \n")
axes.legend()
# fig.savefig("images/moran_selection_invasion_1000.png", dpi=300)

# %% [markdown]
# ## Problem 2
#
# Moran Process with r=0.99 but starting at type A frequency of 0.5

# %%
@njit
def wright_fisher_process(freq,N,r,T_max):
    """
    wright_fisher_equation 
    Returns the frequency of type A and type B in the Wright-Fisher process with selection.

    Parameters
    ----------
    freq: array
        Initial frequency of type A and type B in the population.
    N: int
        Total population size.
    r: float
        Relative fitness of type A compared to type B. 
    T_max: int
        Maximum number of generations(to prevent infinite loops)
    """
    freq = np.asarray(freq)
    freq_array = np.zeros((T_max,2))
    freq_array[0,:] = freq
    for t in range(1,T_max):
        total_fitness = freq_array[t-1,0]*r + freq_array[t-1,1]
        reproduction_probs =[
            (freq_array[t-1,0]*r)/total_fitness, # Probability of choosing type A for reproduction
            (freq_array[t-1,1])/total_fitness     # Probability of choosing type B for reproduction
        ]
        
        # The binomial distribution models the number of successes (type A offspring) in N independent trials (offspring), 
        # where the probability of success on each trial is given by the reproduction probability of type A.
        freq_array[t,0] = np.random.binomial(N, reproduction_probs[0])/N
        freq_array[t,1] = 1 - freq_array[t,0]
        
        # Check for fixation
        if freq_array[t,0] == 0 or freq_array[t,0] == 1:
            return freq_array[:t+1,:]
    print("Maximum generations reached without fixation")
    return freq_array

# %%
# population size
N_wf = 100

# Maximum number of generations(to prevent infinite loops)
T_max = int(1e6)

# Number of runs
Nt_wf = 1000

# Relative fitness of type A compared to type B
r = 0.99

# %%
# %%time

# This cell is not essential for the assignment, 
# It is just here to compile the njit function before we run the actual simulations in the next cell.

# Initial frequency of type A and type B in the population
freq = [0.5, 0.5]
 

# Run the Wright-Fisher process
freq = wright_fisher_process(freq,N_wf,r,T_max)

# final frequency of type A and type B in the population
freq[-1]
# Out:
# CPU times: user 1.85 ms, sys: 3.97 ms, total: 5.82 ms
# Wall time: 5.83 ms
# array([1., 0.])

# %%
# %%time

## Find fixation probabilites
fixation_probs = np.zeros(2)
sample_trajectory = []
freq_ini = [0.5, 0.5]

for run in range(Nt_wf):

    # Run the Wright-Fisher process
    freq = wright_fisher_process(freq_ini.copy(),N_wf,r,T_max)
    fixation_probs += freq[-1]
    
    print(f"Run {run+1}/{Nt_wf}")
  
# Normalize to get probabilities  
fixation_probs /= Nt_wf
# Out:
# Run 1/1000
# Run 2/1000
# Run 3/1000
# Run 4/1000
# Run 5/1000
# Run 6/1000
# Run 7/1000
# Run 8/1000
# Run 9/1000
# Run 10/1000
# Run 11/1000
# Run 12/1000
# Run 13/1000
# Run 14/1000
# Run 15/1000
# Run 16/1000
# Run 17/1000
# Run 18/1000
# Run 19/1000
# Run 20/1000
# Run 21/1000
# Run 22/1000
# Run 23/1000
# Run 24/1000
# Run 25/1000
# Run 26/1000
# Run 27/1000
# Run 28/1000
# Run 29/1000
# Run 30/1000
# Run 31/1000
# Run 32/1000
# Run 33/1000
# Run 34/1000
# Run 35/1000
# Run 36/1000
# Run 37/1000
# Run 38/1000
# Run 39/1000
# Run 40/1000
# Run 41/1000
# Run 42/1000
# Run 43/1000
# Run 44/1000
# Run 45/1000
# Run 46/1000
# Run 47/1000
# Run 48/1000
# Run 49/1000
# Run 50/1000
# Run 51/1000
# Run 52/1000
# Run 53/1000
# Run 54/1000
# Run 55/1000
# Run 56/1000
# Run 57/1000
# Run 58/1000
# Run 59/1000
# Run 60/1000
# Run 61/1000
# Run 62/1000
# Run 63/1000
# Run 64/1000
# Run 65/1000
# Run 66/1000
# Run 67/1000
# Run 68/1000
# Run 69/1000
# Run 70/1000
# Run 71/1000
# Run 72/1000
# Run 73/1000
# Run 74/1000
# Run 75/1000
# Run 76/1000
# Run 77/1000
# Run 78/1000
# Run 79/1000
# Run 80/1000
# Run 81/1000
# Run 82/1000
# Run 83/1000
# Run 84/1000
# Run 85/1000
# Run 86/1000
# Run 87/1000
# Run 88/1000
# Run 89/1000
# Run 90/1000
# Run 91/1000
# Run 92/1000
# Run 93/1000
# Run 94/1000
# Run 95/1000
# Run 96/1000
# Run 97/1000
# Run 98/1000
# Run 99/1000
# Run 100/1000
# Run 101/1000
# Run 102/1000
# Run 103/1000
# Run 104/1000
# Run 105/1000
# Run 106/1000
# Run 107/1000
# Run 108/1000
# Run 109/1000
# Run 110/1000
# Run 111/1000
# Run 112/1000
# Run 113/1000
# Run 114/1000
# Run 115/1000
# Run 116/1000
# Run 117/1000
# Run 118/1000
# Run 119/1000
# Run 120/1000
# Run 121/1000
# Run 122/1000
# Run 123/1000
# Run 124/1000
# Run 125/1000
# Run 126/1000
# Run 127/1000
# Run 128/1000
# Run 129/1000
# Run 130/1000
# Run 131/1000
# Run 132/1000
# Run 133/1000
# Run 134/1000
# Run 135/1000
# Run 136/1000
# Run 137/1000
# Run 138/1000
# Run 139/1000
# Run 140/1000
# Run 141/1000
# Run 142/1000
# Run 143/1000
# Run 144/1000
# Run 145/1000
# Run 146/1000
# Run 147/1000
# Run 148/1000
# Run 149/1000
# Run 150/1000
# Run 151/1000
# Run 152/1000
# Run 153/1000
# Run 154/1000
# Run 155/1000
# Run 156/1000
# Run 157/1000
# Run 158/1000
# Run 159/1000
# Run 160/1000
# Run 161/1000
# Run 162/1000
# Run 163/1000
# Run 164/1000
# Run 165/1000
# Run 166/1000
# Run 167/1000
# Run 168/1000
# Run 169/1000
# Run 170/1000
# Run 171/1000
# Run 172/1000
# Run 173/1000
# Run 174/1000
# Run 175/1000
# Run 176/1000
# Run 177/1000
# Run 178/1000
# Run 179/1000
# Run 180/1000
# Run 181/1000
# Run 182/1000
# Run 183/1000
# Run 184/1000
# Run 185/1000
# Run 186/1000
# Run 187/1000
# Run 188/1000
# Run 189/1000
# Run 190/1000
# Run 191/1000
# Run 192/1000
# Run 193/1000
# Run 194/1000
# Run 195/1000
# Run 196/1000
# Run 197/1000
# Run 198/1000
# Run 199/1000
# Run 200/1000
# Run 201/1000
# Run 202/1000
# Run 203/1000
# Run 204/1000
# Run 205/1000
# Run 206/1000
# Run 207/1000
# Run 208/1000
# Run 209/1000
# Run 210/1000
# Run 211/1000
# Run 212/1000
# Run 213/1000
# Run 214/1000
# Run 215/1000
# Run 216/1000
# Run 217/1000
# Run 218/1000
# Run 219/1000
# Run 220/1000
# Run 221/1000
# Run 222/1000
# Run 223/1000
# Run 224/1000
# Run 225/1000
# Run 226/1000
# Run 227/1000
# Run 228/1000
# Run 229/1000
# Run 230/1000
# Run 231/1000
# Run 232/1000
# Run 233/1000
# Run 234/1000
# Run 235/1000
# Run 236/1000
# Run 237/1000
# Run 238/1000
# Run 239/1000
# Run 240/1000
# Run 241/1000
# Run 242/1000
# Run 243/1000
# Run 244/1000
# Run 245/1000
# Run 246/1000
# Run 247/1000
# Run 248/1000
# Run 249/1000
# Run 250/1000
# Run 251/1000
# Run 252/1000
# Run 253/1000
# Run 254/1000
# Run 255/1000
# Run 256/1000
# Run 257/1000
# Run 258/1000
# Run 259/1000
# Run 260/1000
# Run 261/1000
# Run 262/1000
# Run 263/1000
# Run 264/1000
# Run 265/1000
# Run 266/1000
# Run 267/1000
# Run 268/1000
# Run 269/1000
# Run 270/1000
# Run 271/1000
# Run 272/1000
# Run 273/1000
# Run 274/1000
# Run 275/1000
# Run 276/1000
# Run 277/1000
# Run 278/1000
# Run 279/1000
# Run 280/1000
# Run 281/1000
# Run 282/1000
# Run 283/1000
# Run 284/1000
# Run 285/1000
# Run 286/1000
# Run 287/1000
# Run 288/1000
# Run 289/1000
# Run 290/1000
# Run 291/1000
# Run 292/1000
# Run 293/1000
# Run 294/1000
# Run 295/1000
# Run 296/1000
# Run 297/1000
# Run 298/1000
# Run 299/1000
# Run 300/1000
# Run 301/1000
# Run 302/1000
# Run 303/1000
# Run 304/1000
# Run 305/1000
# Run 306/1000
# Run 307/1000
# Run 308/1000
# Run 309/1000
# Run 310/1000
# Run 311/1000
# Run 312/1000
# Run 313/1000
# Run 314/1000
# Run 315/1000
# Run 316/1000
# Run 317/1000
# Run 318/1000
# Run 319/1000
# Run 320/1000
# Run 321/1000
# Run 322/1000
# Run 323/1000
# Run 324/1000
# Run 325/1000
# Run 326/1000
# Run 327/1000
# Run 328/1000
# Run 329/1000
# Run 330/1000
# Run 331/1000
# Run 332/1000
# Run 333/1000
# Run 334/1000
# Run 335/1000
# Run 336/1000
# Run 337/1000
# Run 338/1000
# Run 339/1000
# Run 340/1000
# Run 341/1000
# Run 342/1000
# Run 343/1000
# Run 344/1000
# Run 345/1000
# Run 346/1000
# Run 347/1000
# Run 348/1000
# Run 349/1000
# Run 350/1000
# Run 351/1000
# Run 352/1000
# Run 353/1000
# Run 354/1000
# Run 355/1000
# Run 356/1000
# Run 357/1000
# Run 358/1000
# Run 359/1000
# Run 360/1000
# Run 361/1000
# Run 362/1000
# Run 363/1000
# Run 364/1000
# Run 365/1000
# Run 366/1000
# Run 367/1000
# Run 368/1000
# Run 369/1000
# Run 370/1000
# Run 371/1000
# Run 372/1000
# Run 373/1000
# Run 374/1000
# Run 375/1000
# Run 376/1000
# Run 377/1000
# Run 378/1000
# Run 379/1000
# Run 380/1000
# Run 381/1000
# Run 382/1000
# Run 383/1000
# Run 384/1000
# Run 385/1000
# Run 386/1000
# Run 387/1000
# Run 388/1000
# Run 389/1000
# Run 390/1000
# Run 391/1000
# Run 392/1000
# Run 393/1000
# Run 394/1000
# Run 395/1000
# Run 396/1000
# Run 397/1000
# Run 398/1000
# Run 399/1000
# Run 400/1000
# Run 401/1000
# Run 402/1000
# Run 403/1000
# Run 404/1000
# Run 405/1000
# Run 406/1000
# Run 407/1000
# Run 408/1000
# Run 409/1000
# Run 410/1000
# Run 411/1000
# Run 412/1000
# Run 413/1000
# Run 414/1000
# Run 415/1000
# Run 416/1000
# Run 417/1000
# Run 418/1000
# Run 419/1000
# Run 420/1000
# Run 421/1000
# Run 422/1000
# Run 423/1000
# Run 424/1000
# Run 425/1000
# Run 426/1000
# Run 427/1000
# Run 428/1000
# Run 429/1000
# Run 430/1000
# Run 431/1000
# Run 432/1000
# Run 433/1000
# Run 434/1000
# Run 435/1000
# Run 436/1000
# Run 437/1000
# Run 438/1000
# Run 439/1000
# Run 440/1000
# Run 441/1000
# Run 442/1000
# Run 443/1000
# Run 444/1000
# Run 445/1000
# Run 446/1000
# Run 447/1000
# Run 448/1000
# Run 449/1000
# Run 450/1000
# Run 451/1000
# Run 452/1000
# Run 453/1000
# Run 454/1000
# Run 455/1000
# Run 456/1000
# Run 457/1000
# Run 458/1000
# Run 459/1000
# Run 460/1000
# Run 461/1000
# Run 462/1000
# Run 463/1000
# Run 464/1000
# Run 465/1000
# Run 466/1000
# Run 467/1000
# Run 468/1000
# Run 469/1000
# Run 470/1000
# Run 471/1000
# Run 472/1000
# Run 473/1000
# Run 474/1000
# Run 475/1000
# Run 476/1000
# Run 477/1000
# Run 478/1000
# Run 479/1000
# Run 480/1000
# Run 481/1000
# Run 482/1000
# Run 483/1000
# Run 484/1000
# Run 485/1000
# Run 486/1000
# Run 487/1000
# Run 488/1000
# Run 489/1000
# Run 490/1000
# Run 491/1000
# Run 492/1000
# Run 493/1000
# Run 494/1000
# Run 495/1000
# Run 496/1000
# Run 497/1000
# Run 498/1000
# Run 499/1000
# Run 500/1000
# Run 501/1000
# Run 502/1000
# Run 503/1000
# Run 504/1000
# Run 505/1000
# Run 506/1000
# Run 507/1000
# Run 508/1000
# Run 509/1000
# Run 510/1000
# Run 511/1000
# Run 512/1000
# Run 513/1000
# Run 514/1000
# Run 515/1000
# Run 516/1000
# Run 517/1000
# Run 518/1000
# Run 519/1000
# Run 520/1000
# Run 521/1000
# Run 522/1000
# Run 523/1000
# Run 524/1000
# Run 525/1000
# Run 526/1000
# Run 527/1000
# Run 528/1000
# Run 529/1000
# Run 530/1000
# Run 531/1000
# Run 532/1000
# Run 533/1000
# Run 534/1000
# Run 535/1000
# Run 536/1000
# Run 537/1000
# Run 538/1000
# Run 539/1000
# Run 540/1000
# Run 541/1000
# Run 542/1000
# Run 543/1000
# Run 544/1000
# Run 545/1000
# Run 546/1000
# Run 547/1000
# Run 548/1000
# Run 549/1000
# Run 550/1000
# Run 551/1000
# Run 552/1000
# Run 553/1000
# Run 554/1000
# Run 555/1000
# Run 556/1000
# Run 557/1000
# Run 558/1000
# Run 559/1000
# Run 560/1000
# Run 561/1000
# Run 562/1000
# Run 563/1000
# Run 564/1000
# Run 565/1000
# Run 566/1000
# Run 567/1000
# Run 568/1000
# Run 569/1000
# Run 570/1000
# Run 571/1000
# Run 572/1000
# Run 573/1000
# Run 574/1000
# Run 575/1000
# Run 576/1000
# Run 577/1000
# Run 578/1000
# Run 579/1000
# Run 580/1000
# Run 581/1000
# Run 582/1000
# Run 583/1000
# Run 584/1000
# Run 585/1000
# Run 586/1000
# Run 587/1000
# Run 588/1000
# Run 589/1000
# Run 590/1000
# Run 591/1000
# Run 592/1000
# Run 593/1000
# Run 594/1000
# Run 595/1000
# Run 596/1000
# Run 597/1000
# Run 598/1000
# Run 599/1000
# Run 600/1000
# Run 601/1000
# Run 602/1000
# Run 603/1000
# Run 604/1000
# Run 605/1000
# Run 606/1000
# Run 607/1000
# Run 608/1000
# Run 609/1000
# Run 610/1000
# Run 611/1000
# Run 612/1000
# Run 613/1000
# Run 614/1000
# Run 615/1000
# Run 616/1000
# Run 617/1000
# Run 618/1000
# Run 619/1000
# Run 620/1000
# Run 621/1000
# Run 622/1000
# Run 623/1000
# Run 624/1000
# Run 625/1000
# Run 626/1000
# Run 627/1000
# Run 628/1000
# Run 629/1000
# Run 630/1000
# Run 631/1000
# Run 632/1000
# Run 633/1000
# Run 634/1000
# Run 635/1000
# Run 636/1000
# Run 637/1000
# Run 638/1000
# Run 639/1000
# Run 640/1000
# Run 641/1000
# Run 642/1000
# Run 643/1000
# Run 644/1000
# Run 645/1000
# Run 646/1000
# Run 647/1000
# Run 648/1000
# Run 649/1000
# Run 650/1000
# Run 651/1000
# Run 652/1000
# Run 653/1000
# Run 654/1000
# Run 655/1000
# Run 656/1000
# Run 657/1000
# Run 658/1000
# Run 659/1000
# Run 660/1000
# Run 661/1000
# Run 662/1000
# Run 663/1000
# Run 664/1000
# Run 665/1000
# Run 666/1000
# Run 667/1000
# Run 668/1000
# Run 669/1000
# Run 670/1000
# Run 671/1000
# Run 672/1000
# Run 673/1000
# Run 674/1000
# Run 675/1000
# Run 676/1000
# Run 677/1000
# Run 678/1000
# Run 679/1000
# Run 680/1000
# Run 681/1000
# Run 682/1000
# Run 683/1000
# Run 684/1000
# Run 685/1000
# Run 686/1000
# Run 687/1000
# Run 688/1000
# Run 689/1000
# Run 690/1000
# Run 691/1000
# Run 692/1000
# Run 693/1000
# Run 694/1000
# Run 695/1000
# Run 696/1000
# Run 697/1000
# Run 698/1000
# Run 699/1000
# Run 700/1000
# Run 701/1000
# Run 702/1000
# Run 703/1000
# Run 704/1000
# Run 705/1000
# Run 706/1000
# Run 707/1000
# Run 708/1000
# Run 709/1000
# Run 710/1000
# Run 711/1000
# Run 712/1000
# Run 713/1000
# Run 714/1000
# Run 715/1000
# Run 716/1000
# Run 717/1000
# Run 718/1000
# Run 719/1000
# Run 720/1000
# Run 721/1000
# Run 722/1000
# Run 723/1000
# Run 724/1000
# Run 725/1000
# Run 726/1000
# Run 727/1000
# Run 728/1000
# Run 729/1000
# Run 730/1000
# Run 731/1000
# Run 732/1000
# Run 733/1000
# Run 734/1000
# Run 735/1000
# Run 736/1000
# Run 737/1000
# Run 738/1000
# Run 739/1000
# Run 740/1000
# Run 741/1000
# Run 742/1000
# Run 743/1000
# Run 744/1000
# Run 745/1000
# Run 746/1000
# Run 747/1000
# Run 748/1000
# Run 749/1000
# Run 750/1000
# Run 751/1000
# Run 752/1000
# Run 753/1000
# Run 754/1000
# Run 755/1000
# Run 756/1000
# Run 757/1000
# Run 758/1000
# Run 759/1000
# Run 760/1000
# Run 761/1000
# Run 762/1000
# Run 763/1000
# Run 764/1000
# Run 765/1000
# Run 766/1000
# Run 767/1000
# Run 768/1000
# Run 769/1000
# Run 770/1000
# Run 771/1000
# Run 772/1000
# Run 773/1000
# Run 774/1000
# Run 775/1000
# Run 776/1000
# Run 777/1000
# Run 778/1000
# Run 779/1000
# Run 780/1000
# Run 781/1000
# Run 782/1000
# Run 783/1000
# Run 784/1000
# Run 785/1000
# Run 786/1000
# Run 787/1000
# Run 788/1000
# Run 789/1000
# Run 790/1000
# Run 791/1000
# Run 792/1000
# Run 793/1000
# Run 794/1000
# Run 795/1000
# Run 796/1000
# Run 797/1000
# Run 798/1000
# Run 799/1000
# Run 800/1000
# Run 801/1000
# Run 802/1000
# Run 803/1000
# Run 804/1000
# Run 805/1000
# Run 806/1000
# Run 807/1000
# Run 808/1000
# Run 809/1000
# Run 810/1000
# Run 811/1000
# Run 812/1000
# Run 813/1000
# Run 814/1000
# Run 815/1000
# Run 816/1000
# Run 817/1000
# Run 818/1000
# Run 819/1000
# Run 820/1000
# Run 821/1000
# Run 822/1000
# Run 823/1000
# Run 824/1000
# Run 825/1000
# Run 826/1000
# Run 827/1000
# Run 828/1000
# Run 829/1000
# Run 830/1000
# Run 831/1000
# Run 832/1000
# Run 833/1000
# Run 834/1000
# Run 835/1000
# Run 836/1000
# Run 837/1000
# Run 838/1000
# Run 839/1000
# Run 840/1000
# Run 841/1000
# Run 842/1000
# Run 843/1000
# Run 844/1000
# Run 845/1000
# Run 846/1000
# Run 847/1000
# Run 848/1000
# Run 849/1000
# Run 850/1000
# Run 851/1000
# Run 852/1000
# Run 853/1000
# Run 854/1000
# Run 855/1000
# Run 856/1000
# Run 857/1000
# Run 858/1000
# Run 859/1000
# Run 860/1000
# Run 861/1000
# Run 862/1000
# Run 863/1000
# Run 864/1000
# Run 865/1000
# Run 866/1000
# Run 867/1000
# Run 868/1000
# Run 869/1000
# Run 870/1000
# Run 871/1000
# Run 872/1000
# Run 873/1000
# Run 874/1000
# Run 875/1000
# Run 876/1000
# Run 877/1000
# Run 878/1000
# Run 879/1000
# Run 880/1000
# Run 881/1000
# Run 882/1000
# Run 883/1000
# Run 884/1000
# Run 885/1000
# Run 886/1000
# Run 887/1000
# Run 888/1000
# Run 889/1000
# Run 890/1000
# Run 891/1000
# Run 892/1000
# Run 893/1000
# Run 894/1000
# Run 895/1000
# Run 896/1000
# Run 897/1000
# Run 898/1000
# Run 899/1000
# Run 900/1000
# Run 901/1000
# Run 902/1000
# Run 903/1000
# Run 904/1000
# Run 905/1000
# Run 906/1000
# Run 907/1000
# Run 908/1000
# Run 909/1000
# Run 910/1000
# Run 911/1000
# Run 912/1000
# Run 913/1000
# Run 914/1000
# Run 915/1000
# Run 916/1000
# Run 917/1000
# Run 918/1000
# Run 919/1000
# Run 920/1000
# Run 921/1000
# Run 922/1000
# Run 923/1000
# Run 924/1000
# Run 925/1000
# Run 926/1000
# Run 927/1000
# Run 928/1000
# Run 929/1000
# Run 930/1000
# Run 931/1000
# Run 932/1000
# Run 933/1000
# Run 934/1000
# Run 935/1000
# Run 936/1000
# Run 937/1000
# Run 938/1000
# Run 939/1000
# Run 940/1000
# Run 941/1000
# Run 942/1000
# Run 943/1000
# Run 944/1000
# Run 945/1000
# Run 946/1000
# Run 947/1000
# Run 948/1000
# Run 949/1000
# Run 950/1000
# Run 951/1000
# Run 952/1000
# Run 953/1000
# Run 954/1000
# Run 955/1000
# Run 956/1000
# Run 957/1000
# Run 958/1000
# Run 959/1000
# Run 960/1000
# Run 961/1000
# Run 962/1000
# Run 963/1000
# Run 964/1000
# Run 965/1000
# Run 966/1000
# Run 967/1000
# Run 968/1000
# Run 969/1000
# Run 970/1000
# Run 971/1000
# Run 972/1000
# Run 973/1000
# Run 974/1000
# Run 975/1000
# Run 976/1000
# Run 977/1000
# Run 978/1000
# Run 979/1000
# Run 980/1000
# Run 981/1000
# Run 982/1000
# Run 983/1000
# Run 984/1000
# Run 985/1000
# Run 986/1000
# Run 987/1000
# Run 988/1000
# Run 989/1000
# Run 990/1000
# Run 991/1000
# Run 992/1000
# Run 993/1000
# Run 994/1000
# Run 995/1000
# Run 996/1000
# Run 997/1000
# Run 998/1000
# Run 999/1000
# Run 1000/1000
# CPU times: user 607 ms, sys: 4.98 ms, total: 612 ms
# Wall time: 614 ms

# %%
fig, axes = plt.subplots(figsize=(16,9))
axes.plot(freq[:,0], label=f"Frequency of Type A with fitness = {r:.2f}", color='c')
axes.plot(freq[:,1], label=f"Frequency of Type B with fitness = {1.0}", color='r')
axes.legend()
axes.set_xlabel("Generations")
axes.set_ylabel("Frequency")
axes.set_title("Wright-Fisher Process(with Selection): Frequency vs Generations")
# fig.savefig("images/wright_fisher_selection_trajectory_p2.png", dpi=300)
# Out:
# Text(0.5, 1.0, 'Wright-Fisher Process(with Selection): Frequency vs Generations')

# %%
def wf_fixation_probability(r,i,N):
    """
    wf_fixation_probability 
    Returns the probability of invasion of a single mutant of type A in a population of type B in the Wright-Fisher Process with selection.

    Parameters
    ----------
    r: float
        Relative fitness of type A compared to type B. 
    i: int
        Initial number of mutants of type A in the population.
    N: int
        Total population size.
    """
    p0 = i/N
    alpha = N*(r-1)
    if alpha == 0:
        return p0
    else:
        prob = (1 - np.exp(-2*alpha*p0))/(1 - np.exp(-2*alpha))
    return prob

# %%
# Invasion probability from analytical formula
# The formula requires the ratio 1+s:1, so we rescale,
# 1/r is the relative fitness of type B compared to type A, which can then 
# be expressed in the form 1+s:1, where s is the selection coefficient.
prob = wf_fixation_probability(1/r, N_wf//2, N_wf)
prob
# Out:
# np.float64(0.7330399166129685)

# %%
fig, axes = plt.subplots(figsize=(6,7))
axes.bar([0,1], fixation_probs, color=['c','r'])
axes.annotate(f"{fixation_probs[0]:.4f}", xy=(0, fixation_probs[0]), xytext=(0, fixation_probs[0]+0.05), ha='center', fontsize=15, fontweight='bold', color='black')
axes.annotate(f"{fixation_probs[1]:.4f}", xy=(1, fixation_probs[1]), xytext=(1, fixation_probs[1]+0.05), ha='center', fontsize=15, fontweight='bold', color='black')
axes.axhline(y=1-prob, color='r', linestyle='--', label=f'Theoretical Fixation Probability of A = {1-prob:.3f}')
axes.set_xticks([0,1])
axes.set_xticklabels(['Type A','Type B'])
axes.set_ylabel("Fixation Probability")
axes.set_ylim(0,1.3)
axes.set_title("\n Fixation Probabilities from Wright-Fisher Process \n")
axes.legend()
# fig.savefig("images/wright_fisher_selection_p2_100000.png", dpi=300)
